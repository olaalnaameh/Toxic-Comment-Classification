# %%
from collections import Counter
import collections
import pickle
import string
import matplotlib.pyplot as plt
import pandas as pd
from nltk import ngrams

from nltk.tokenize import word_tokenize
from nltk.util import ngrams

def saveInFile(data,fileName):
    filehandler = open(fileName+".p", "wb")
    pickle.dump(data, filehandler)
    filehandler.close()

def get_ngrams(sentence, n ):
    n_grams = ngrams(word_tokenize(sentence), n)
    return [ ' '.join(grams) for grams in n_grams]

train = pickle.load(open('train.p','rb'))
x_train=train['comment_text']
y_train=train.iloc[:, 1:]

# %%
wordsNonClean = Counter()
for item in train[(train['clean'] == 0)]['comment_text'].tolist():
    wordsNonClean.update(get_ngrams(item,2))
    wordsNonClean.update(get_ngrams(item, 3))
    wordsNonClean.update(item.split(" "))
print('NonCleanDict',wordsNonClean)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
wordsClean = Counter()
for item in train[(train['clean'] == 1)]['comment_text'].tolist():
    wordsClean.update(get_ngrams(item,2))
    wordsClean.update(get_ngrams(item, 3))
    wordsClean.update(item.split(" "))
print('CleanDict',wordsClean)
# Out:
# C:\Users\ola.alnaameh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: generator 'ngrams' raised StopIteration
# CleanDict
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
sumClean=sum(wordsClean.values())
sumNonClean=sum(wordsNonClean.values())

print(sumClean,sumNonClean)
# Out:
# 28834281 2519986

# %%
CleanDict = dict()
for ele in wordsClean:
    sumWords=0
    if ele in list(wordsNonClean.elements()):
        sumWords=sumWords+wordsNonClean[ele]
    
    div=(wordsClean[ele]/sumClean)/((sumWords+1)/(sumNonClean))
    CleanDict.update({ele:div})

print('CleanDict',CleanDict)
saveInFile(CleanDict,'CleanDict')

# %%
NonCleanDict = dict()
for ele in wordsNonClean:
    sumWords=0
    if ele in list(wordsClean.elements()):
        sumWords=sumWords+wordsClean[ele]
    print(ele)
    div=(wordsNonClean[ele]/sumNonClean)/((sumWords+1)/( sumClean))
    NonCleanDict.update({ele:div})

print('NonCleanDict',NonCleanDict)
saveInFile(NonCleanDict,'NonCleanDict')
# Out:
# cocksucker before
# before -PRON-
# -PRON- piss
# piss around
# around on
# on -PRON-
# -PRON- work
# cocksucker before -PRON-
# before -PRON- piss
# -PRON- piss around
# piss around on
# around on -PRON-
# on -PRON- work
# cocksucker
# before
# -PRON-
# piss
# around
# on
# work
# hey what
# what be
# be -PRON-
# -PRON- talk
# talk what
# -PRON- a
# a exclusive
# exclusive group
# group of
# of some
# some wp
# wp talibanswho
# talibanswho be
# be good
# good at
# at destroy
# destroy selfappoint
# selfappoint purist
# purist who
# who gang
# gang up
# up any
# any one
# one who
# who ask
# ask -PRON-
# -PRON- question
# question abt
# abt -PRON-
# -PRON- antisocial
# antisocial and
# and destructive
# destructive noncontribution
# noncontribution at
# at wp
# wp ask
# ask sityush
# sityush to
# to clean
# clean up
# up -PRON-
# -PRON- behavior
# behavior than
# than issue
# issue -PRON-
# -PRON- nonsensical
# nonsensical warning
# hey what be
# what be -PRON-
# be -PRON- talk
# -PRON- talk what
# talk what be
# be -PRON- a
# -PRON- a exclusive
# a exclusive group
# exclusive group of
# group of some
# of some wp
# some wp talibanswho
# wp talibanswho be
# talibanswho be good
# be good at
# good at destroy
# at destroy selfappoint
# destroy selfappoint purist
# selfappoint purist who
# purist who gang
# who gang up
# gang up any
# up any one
# any one who
# one who ask
# who ask -PRON-
# ask -PRON- question
# -PRON- question abt
# question abt -PRON-
# abt -PRON- antisocial
# -PRON- antisocial and
# antisocial and destructive
# and destructive noncontribution
# destructive noncontribution at
# noncontribution at wp
# at wp ask
# wp ask sityush
# ask sityush to
# sityush to clean
# to clean up
# clean up -PRON-
# up -PRON- behavior
# -PRON- behavior than
# behavior than issue
# than issue -PRON-
# issue -PRON- nonsensical
# -PRON- nonsensical warning
# hey
# what
# be
# talk
# a
# exclusive
# group
# of
# some
# wp
# talibanswho
# good
# at
# destroy
# selfappoint
# purist
# who
# gang
# up
# any
# one
# ask
# question
# abt
# antisocial
# and
# destructive
# noncontribution
# sityush
# to
# clean
# behavior
# than
# issue
# nonsensical
# warning
# bye do
# do not
# not look
# look come
# come or
# or think
# think of
# of comm
# comm back
# back tosser
# bye do not
# do not look
# not look come
# look come or
# come or think
# or think of
# think of comm
# of comm back
# comm back tosser
# bye
# do
# not
# look
# come
# or
# think
# comm
# back
# tosser
# -PRON- be
# be gay
# gay or
# or antisemmitian
# antisemmitian archangel
# archangel white
# white tiger
# tiger meow
# meow greetingshhh
# greetingshhh uh
# uh there
# there be
# be two
# two way
# way why
# why -PRON-
# -PRON- do
# do erase
# erase -PRON-
# -PRON- comment
# comment about
# about ww
# ww that
# that holocaust
# holocaust be
# be brutally
# brutally slay
# slay of
# of jews
# jews and
# and not
# not gaysgypsysslavsanyone
# gaysgypsysslavsanyone if
# if -PRON-
# be antisemitian
# antisemitian than
# than shave
# shave -PRON-
# -PRON- head
# head bald
# bald and
# and go
# go to
# to the
# the skinhead
# skinhead meeting
# meeting if
# -PRON- doubt
# doubt word
# word of
# of the
# the bible
# bible that
# that homosexuality
# homosexuality be
# be a
# a deadly
# deadly sin
# sin make
# make a
# a pentagram
# pentagram tatoo
# tatoo on
# -PRON- forehead
# forehead go
# the satanistic
# satanistic masse
# masse with
# with -PRON-
# -PRON- gay
# gay pal
# pal ﻿1
# ﻿1 and
# and last
# last warn
# warn -PRON-
# -PRON- fuck
# fuck gay
# gay i
# i will
# will not
# not appreciate
# appreciate if
# if any
# any much
# much nazi
# nazi shwain
# shwain would
# would write
# write in
# in -PRON-
# -PRON- page
# page i
# i do
# not wish
# wish to
# to talk
# talk to
# to -PRON-
# -PRON- anymore
# anymore beware
# beware of
# the dark
# dark side
# -PRON- be gay
# be gay or
# gay or antisemmitian
# or antisemmitian archangel
# antisemmitian archangel white
# archangel white tiger
# white tiger meow
# tiger meow greetingshhh
# meow greetingshhh uh
# greetingshhh uh there
# uh there be
# there be two
# be two way
# two way why
# way why -PRON-
# why -PRON- do
# -PRON- do erase
# do erase -PRON-
# erase -PRON- comment
# -PRON- comment about
# comment about ww
# about ww that
# ww that holocaust
# that holocaust be
# holocaust be brutally
# be brutally slay
# brutally slay of
# slay of jews
# of jews and
# jews and not
# and not gaysgypsysslavsanyone
# not gaysgypsysslavsanyone if
# gaysgypsysslavsanyone if -PRON-
# if -PRON- be
# -PRON- be antisemitian
# be antisemitian than
# antisemitian than shave
# than shave -PRON-
# shave -PRON- head
# -PRON- head bald
# head bald and
# bald and go
# and go to
# go to the
# to the skinhead
# the skinhead meeting
# skinhead meeting if
# meeting if -PRON-
# if -PRON- doubt
# -PRON- doubt word
# doubt word of
# word of the
# of the bible
# the bible that
# bible that homosexuality
# that homosexuality be
# homosexuality be a
# be a deadly
# a deadly sin
# deadly sin make
# sin make a
# make a pentagram
# a pentagram tatoo
# pentagram tatoo on
# tatoo on -PRON-
# on -PRON- forehead
# -PRON- forehead go
# forehead go to
# to the satanistic
# the satanistic masse
# satanistic masse with
# masse with -PRON-
# with -PRON- gay
# -PRON- gay pal
# gay pal ﻿1
# pal ﻿1 and
# ﻿1 and last
# and last warn
# last warn -PRON-
# warn -PRON- fuck
# -PRON- fuck gay
# fuck gay i
# gay i will
# i will not
# will not appreciate
# not appreciate if
# appreciate if any
# if any much
# any much nazi
# much nazi shwain
# nazi shwain would
# shwain would write
# would write in
# write in -PRON-
# in -PRON- page
# -PRON- page i
# page i do
# i do not
# do not wish
# not wish to
# wish to talk
# to talk to
# talk to -PRON-
# to -PRON- anymore
# -PRON- anymore beware
# anymore beware of
# beware of the
# of the dark
# the dark side
# gay
# antisemmitian
# archangel
# white
# tiger
# meow
# greetingshhh
# uh
# there
# two
# way
# why
# erase
# comment
# about
# ww
# that
# holocaust
# brutally
# slay
# jews
# gaysgypsysslavsanyone
# if
# antisemitian
# shave
# head
# bald
# go
# the
# skinhead
# meeting
# doubt
# word
# bible
# homosexuality
# deadly
# sin
# make
# pentagram
# tatoo
# forehead
# satanistic
# masse
# with
# pal
# ﻿1
# last
# warn
# fuck
# i
# will
# appreciate
# much
# nazi
# shwain
# would
# write
# in
# page
# wish
# anymore
# beware
# dark
# side
# fuck -PRON-
# -PRON- filthy
# filthy mother
# mother in
# in the
# the ass
# ass spin-dry
# fuck -PRON- filthy
# -PRON- filthy mother
# filthy mother in
# mother in the
# in the ass
# the ass spin-dry
# filthy
# mother
# ass
# spin-dry
# be sorry
# sorry -PRON-
# sorry i
# i screw
# screw around
# around with
# with someone
# someone talk
# talk page
# page -PRON-
# be very
# very bad
# bad to
# to do
# do i
# i know
# know how
# how have
# have the
# the template
# template on
# page help
# help -PRON-
# -PRON- assert
# assert -PRON-
# -PRON- dominance
# dominance over
# over -PRON-
# -PRON- i
# know i
# i should
# should bow
# bow down
# down to
# the almighty
# almighty administrator
# administrator but
# but then
# then again
# again -PRON-
# be go
# to go
# go play
# play outsidewith
# outsidewith -PRON-
# -PRON- mom
# -PRON- be sorry
# be sorry -PRON-
# sorry -PRON- be
# be sorry i
# sorry i screw
# i screw around
# screw around with
# around with someone
# with someone talk
# someone talk page
# talk page -PRON-
# page -PRON- be
# -PRON- be very
# be very bad
# very bad to
# bad to do
# to do i
# do i know
# i know how
# know how have
# how have the
# have the template
# the template on
# template on -PRON-
# on -PRON- talk
# -PRON- talk page
# talk page help
# page help -PRON-
# help -PRON- assert
# -PRON- assert -PRON-
# assert -PRON- dominance
# -PRON- dominance over
# dominance over -PRON-
# over -PRON- i
# -PRON- i know
# i know i
# know i should
# i should bow
# should bow down
# bow down to
# down to the
# to the almighty
# the almighty administrator
# almighty administrator but
# administrator but then
# but then again
# then again -PRON-
# again -PRON- be
# -PRON- be go
# be go to
# go to go
# to go play
# go play outsidewith
# play outsidewith -PRON-
# outsidewith -PRON- mom
# sorry
# screw
# someone
# very
# bad
# know
# how
# have
# template
# help
# assert
# dominance
# over
# should
# bow
# down
# almighty
# administrator
# but
# then
# again
# play
# outsidewith
# mom
# get fuck
# fuck up
# up get
# get fuckeeed
# fuckeeed up
# get a
# a drink
# drink that
# that -PRON-
# -PRON- can
# can not
# not put
# put down
# down get
# be fuck
# up right
# right now
# get fuck up
# fuck up get
# up get fuckeeed
# get fuckeeed up
# fuckeeed up get
# up get a
# get a drink
# a drink that
# drink that -PRON-
# that -PRON- can
# -PRON- can not
# can not put
# not put down
# put down get
# down get fuck
# up get fuck
# fuck up -PRON-
# up -PRON- be
# -PRON- be fuck
# be fuck up
# fuck up right
# up right now
# get
# fuckeeed
# drink
# can
# put
# right
# now
# stupid peace
# peace of
# of shit
# shit stop
# stop delete
# delete -PRON-
# -PRON- stuff
# stuff asshole
# asshole go
# go die
# die and
# and fall
# fall in
# in a
# a hole
# hole go
# to hell
# stupid peace of
# peace of shit
# of shit stop
# shit stop delete
# stop delete -PRON-
# delete -PRON- stuff
# -PRON- stuff asshole
# stuff asshole go
# asshole go die
# go die and
# die and fall
# and fall in
# fall in a
# in a hole
# a hole go
# hole go to
# go to hell
# stupid
# peace
# shit
# stop
# delete
# stuff
# asshole
# die
# fall
# hole
# hell
# tony sidaway
# sidaway be
# be obviously
# obviously a
# a fistfuckee
# fistfuckee -PRON-
# -PRON- love
# love a
# a arm
# arm up
# -PRON- ass
# tony sidaway be
# sidaway be obviously
# be obviously a
# obviously a fistfuckee
# a fistfuckee -PRON-
# fistfuckee -PRON- love
# -PRON- love a
# love a arm
# a arm up
# arm up -PRON-
# up -PRON- ass
# tony
# sidaway
# obviously
# fistfuckee
# love
# arm
# -PRON- band
# band page
# page deletion
# deletion -PRON-
# -PRON- think
# think i
# i be
# go delete
# delete the
# the comment
# comment i
# i post
# post on
# page doe
# doe not
# not delete
# -PRON- feeling
# feeling for
# for -PRON-
# -PRON- hasty
# hasty decision
# decision to
# to delete
# -PRON- sir
# sir be
# be still
# still a
# a cocksuck
# cocksuck douche
# douche fuck
# fuck sit
# sit back
# back for
# for a
# a 2
# 2 and
# and think
# think about
# about what
# what -PRON-
# -PRON- life
# life have
# have become
# become do
# do that
# that do
# not take
# take long
# long do
# do -PRON-
# -PRON- no
# no because
# because a
# a i
# be much
# much certainly
# certainly aware
# aware -PRON-
# life be
# a shitstorm
# shitstorm of
# of sit
# sit in
# in front
# front of
# the computer
# computer masturbate
# masturbate to
# to fictional
# fictional creature
# creature -PRON-
# -PRON- attempt
# attempt to
# to get
# get rid
# rid of
# of -PRON-
# be mediocre
# mediocre at
# at well
# well -PRON-
# be constantly
# constantly suck
# suck the
# the dick
# dick of
# of failure
# failure -PRON-
# not want
# want a
# a personal
# personal attack
# attack huh
# huh good
# good too
# too bad
# bad fuckcock
# fuckcock mcdickerson
# mcdickerson -PRON-
# -PRON- have
# have get
# get one
# one from
# from -PRON-
# -PRON- -PRON-
# can go
# go ahead
# ahead and
# and delete
# -PRON- profile
# profile from
# from wikipedia
# wikipedia ill
# ill just
# just make
# make another
# another one
# one and
# and come
# come right
# right back
# back to
# to syrthisss
# syrthisss talk
# page and
# and insult
# insult the
# dick off
# off of
# -PRON- how
# how can
# can -PRON-
# -PRON- shatter
# shatter the
# the dream
# dream of
# of a
# a innocent
# innocent eighteen
# eighteen year
# year old
# old college
# college freshman
# freshman try
# try to
# to make
# a name
# name for
# band doe
# doe that
# that make
# make -PRON-
# -PRON- happy
# happy fuck
# fuck with
# with people
# people because
# because -PRON-
# a overweight
# overweight single
# single old
# old man
# man in
# a deadend
# deadend job
# job do
# -PRON- spot
# spot that
# that perhaps
# perhaps someone
# someone else
# else be
# to follow
# follow -PRON-
# -PRON- dream
# dream and
# and -PRON-
# be try
# to hold
# hold -PRON-
# -PRON- back
# back so
# so somebody
# somebody else
# else can
# can suffer
# suffer like
# like -PRON-
# -PRON- yes
# yes -PRON-
# not make
# make empty
# empty threat
# threat so
# so i
# not be
# be say
# say anything
# anything along
# along the
# the line
# line of
# of ill
# ill hurt
# hurt -PRON-
# -PRON- or
# or ill
# ill eat
# eat the
# the child
# child from
# from within
# within -PRON-
# -PRON- sister
# sister womb
# womb but
# but i
# will say
# say that
# a asshole
# asshole sonofabitch
# sonofabitch mother
# mother fuck
# fuck cock
# cock sucker
# sucker so
# so go
# go eat
# eat some
# some much
# much food
# food and
# and drown
# drown -PRON-
# -PRON- sorrow
# sorrow -PRON-
# -PRON- premature
# premature ejaculate
# ejaculate bald
# bald head
# head fuck
# -PRON- should
# should do
# do something
# something nice
# nice for
# -PRON- maybe
# maybe go
# go grab
# grab a
# a couple
# couple of
# of horny
# horny goat
# goat weed
# weed from
# -PRON- local
# local convenience
# convenience store
# store and
# and jack
# jack off
# off for
# a little
# little long
# long than
# than three
# three minute
# minute tonight
# tonight sincerely
# sincerely a
# asshole that
# that s
# s well
# well than
# than -PRON-
# -PRON- in
# in every
# every way
# -PRON- band page
# band page deletion
# page deletion -PRON-
# deletion -PRON- think
# -PRON- think i
# think i be
# i be go
# be go delete
# go delete the
# delete the comment
# the comment i
# comment i post
# i post on
# post on -PRON-
# talk page doe
# page doe not
# doe not delete
# not delete -PRON-
# delete -PRON- feeling
# -PRON- feeling for
# feeling for -PRON-
# for -PRON- hasty
# -PRON- hasty decision
# hasty decision to
# decision to delete
# to delete -PRON-
# delete -PRON- page
# -PRON- page -PRON-
# page -PRON- sir
# -PRON- sir be
# sir be still
# be still a
# still a cocksuck
# a cocksuck douche
# cocksuck douche fuck
# douche fuck sit
# fuck sit back
# sit back for
# back for a
# for a 2
# a 2 and
# 2 and think
# and think about
# think about what
# about what -PRON-
# what -PRON- life
# -PRON- life have
# life have become
# have become do
# become do that
# do that do
# that do not
# do not take
# not take long
# take long do
# long do -PRON-
# do -PRON- no
# -PRON- no because
# no because a
# because a i
# a i be
# i be much
# be much certainly
# much certainly aware
# certainly aware -PRON-
# aware -PRON- life
# -PRON- life be
# life be a
# be a shitstorm
# a shitstorm of
# shitstorm of sit
# of sit in
# sit in front
# in front of
# front of the
# of the computer
# the computer masturbate
# computer masturbate to
# masturbate to fictional
# to fictional creature
# fictional creature -PRON-
# creature -PRON- attempt
# -PRON- attempt to
# attempt to get
# to get rid
# get rid of
# rid of -PRON-
# of -PRON- be
# -PRON- be mediocre
# be mediocre at
# mediocre at well
# at well -PRON-
# well -PRON- be
# -PRON- be constantly
# be constantly suck
# constantly suck the
# suck the dick
# the dick of
# dick of failure
# of failure -PRON-
# failure -PRON- do
# -PRON- do not
# do not want
# not want a
# want a personal
# a personal attack
# personal attack huh
# attack huh good
# huh good too
# good too bad
# too bad fuckcock
# bad fuckcock mcdickerson
# fuckcock mcdickerson -PRON-
# mcdickerson -PRON- have
# -PRON- have get
# have get one
# get one from
# one from -PRON-
# from -PRON- -PRON-
# -PRON- -PRON- can
# -PRON- can go
# can go ahead
# go ahead and
# ahead and delete
# and delete -PRON-
# delete -PRON- profile
# -PRON- profile from
# profile from wikipedia
# from wikipedia ill
# wikipedia ill just
# ill just make
# just make another
# make another one
# another one and
# one and come
# and come right
# come right back
# right back to
# back to syrthisss
# to syrthisss talk
# syrthisss talk page
# talk page and
# page and insult
# and insult the
# insult the dick
# the dick off
# dick off of
# off of -PRON-
# of -PRON- how
# -PRON- how can
# how can -PRON-
# can -PRON- shatter
# -PRON- shatter the
# shatter the dream
# the dream of
# dream of a
# of a innocent
# a innocent eighteen
# innocent eighteen year
# eighteen year old
# year old college
# old college freshman
# college freshman try
# freshman try to
# try to make
# to make a
# make a name
# a name for
# name for -PRON-
# for -PRON- band
# -PRON- band doe
# band doe that
# doe that make
# that make -PRON-
# make -PRON- happy
# -PRON- happy fuck
# happy fuck with
# fuck with people
# with people because
# people because -PRON-
# because -PRON- be
# -PRON- be a
# be a overweight
# a overweight single
# overweight single old
# single old man
# old man in
# man in a
# in a deadend
# a deadend job
# deadend job do
# job do -PRON-
# do -PRON- spot
# -PRON- spot that
# spot that perhaps
# that perhaps someone
# perhaps someone else
# someone else be
# else be go
# go to follow
# to follow -PRON-
# follow -PRON- dream
# -PRON- dream and
# dream and -PRON-
# and -PRON- be
# -PRON- be try
# be try to
# try to hold
# to hold -PRON-
# hold -PRON- back
# -PRON- back so
# back so somebody
# so somebody else
# somebody else can
# else can suffer
# can suffer like
# suffer like -PRON-
# like -PRON- yes
# -PRON- yes -PRON-
# yes -PRON- do
# -PRON- do i
# do i do
# do not make
# not make empty
# make empty threat
# empty threat so
# threat so i
# so i will
# will not be
# not be say
# be say anything
# say anything along
# anything along the
# along the line
# the line of
# line of ill
# of ill hurt
# ill hurt -PRON-
# hurt -PRON- or
# -PRON- or ill
# or ill eat
# ill eat the
# eat the child
# the child from
# child from within
# from within -PRON-
# within -PRON- sister
# -PRON- sister womb
# sister womb but
# womb but i
# but i will
# i will say
# will say that
# say that -PRON-
# that -PRON- be
# be a asshole
# a asshole sonofabitch
# asshole sonofabitch mother
# sonofabitch mother fuck
# mother fuck cock
# fuck cock sucker
# cock sucker so
# sucker so go
# so go eat
# go eat some
# eat some much
# some much food
# much food and
# food and drown
# and drown -PRON-
# drown -PRON- sorrow
# -PRON- sorrow -PRON-
# sorrow -PRON- premature
# -PRON- premature ejaculate
# premature ejaculate bald
# ejaculate bald head
# bald head fuck
# head fuck -PRON-
# fuck -PRON- should
# -PRON- should do
# should do something
# do something nice
# something nice for
# nice for -PRON-
# for -PRON- maybe
# -PRON- maybe go
# maybe go grab
# go grab a
# grab a couple
# a couple of
# couple of horny
# of horny goat
# horny goat weed
# goat weed from
# weed from -PRON-
# from -PRON- local
# -PRON- local convenience
# local convenience store
# convenience store and
# store and jack
# and jack off
# jack off for
# off for a
# for a little
# a little long
# little long than
# long than three
# than three minute
# three minute tonight
# minute tonight sincerely
# tonight sincerely a
# sincerely a asshole
# a asshole that
# asshole that s
# that s well
# s well than
# well than -PRON-
# than -PRON- in
# -PRON- in every
# in every way
# band
# deletion
# post
# doe
# feeling
# for
# hasty
# decision
# sir
# still
# cocksuck
# douche
# sit
# 2
# life
# become
# take
# long
# no
# because
# certainly
# aware
# shitstorm
# front
# computer
# masturbate
# fictional
# creature
# attempt
# rid
# mediocre
# well
# constantly
# suck
# dick
# failure
# want
# personal
# attack
# huh
# too
# fuckcock
# mcdickerson
# from
# ahead
# profile
# wikipedia
# ill
# just
# another
# syrthisss
# insult
# off
# shatter
# dream
# innocent
# eighteen
# year
# old
# college
# freshman
# try
# name
# happy
# people
# overweight
# single
# man
# deadend
# job
# spot
# perhaps
# else
# follow
# hold
# so
# somebody
# suffer
# like
# yes
# empty
# threat
# say
# anything
# along
# line
# hurt
# eat
# child
# within
# sister
# womb
# sonofabitch
# cock
# sucker
# food
# drown
# sorrow
# premature
# ejaculate
# something
# nice
# maybe
# grab
# couple
# horny
# goat
# weed
# local
# convenience
# store
# jack
# little
# three
# minute
# tonight
# sincerely
# s
# every
# why can
# not -PRON-
# -PRON- believe
# believe how
# how fat
# fat artie
# artie be
# be do
# -PRON- see
# see -PRON-
# -PRON- on
# -PRON- recent
# recent appearence
# appearence on
# on the
# the tonight
# tonight show
# show with
# with jay
# jay leno
# leno -PRON-
# -PRON- look
# look absolutely
# absolutely awful
# awful if
# if i
# i have
# have to
# to put
# put money
# money on
# -PRON- would
# would say
# that artie
# artie lange
# lange be
# a can
# not miss
# miss candidate
# candidate for
# for the
# the dead
# dead pool
# pool kindly
# kindly keep
# keep -PRON-
# -PRON- malicious
# malicious finger
# finger off
# -PRON- above
# above comment
# comment everytime
# everytime -PRON-
# -PRON- remove
# remove -PRON-
# will repost
# repost -PRON-
# why can not
# can not -PRON-
# not -PRON- believe
# -PRON- believe how
# believe how fat
# how fat artie
# fat artie be
# artie be do
# be do -PRON-
# do -PRON- see
# -PRON- see -PRON-
# see -PRON- on
# -PRON- on -PRON-
# on -PRON- recent
# -PRON- recent appearence
# recent appearence on
# appearence on the
# on the tonight
# the tonight show
# tonight show with
# show with jay
# with jay leno
# jay leno -PRON-
# leno -PRON- look
# -PRON- look absolutely
# look absolutely awful
# absolutely awful if
# awful if i
# if i have
# i have to
# have to put
# to put money
# put money on
# money on -PRON-
# on -PRON- -PRON-
# -PRON- -PRON- would
# -PRON- would say
# would say that
# say that artie
# that artie lange
# artie lange be
# lange be a
# be a can
# a can not
# can not miss
# not miss candidate
# miss candidate for
# candidate for the
# for the dead
# the dead pool
# dead pool kindly
# pool kindly keep
# kindly keep -PRON-
# keep -PRON- malicious
# -PRON- malicious finger
# malicious finger off
# finger off of
# of -PRON- above
# -PRON- above comment
# above comment everytime
# comment everytime -PRON-
# everytime -PRON- remove
# -PRON- remove -PRON-
# remove -PRON- i
# -PRON- i will
# i will repost
# will repost -PRON-
# believe
# fat
# artie
# see
# recent
# appearence
# show
# jay
# leno
# absolutely
# awful
# money
# lange
# miss
# candidate
# dead
# pool
# kindly
# keep
# malicious
# finger
# above
# everytime
# remove
# repost
# all of
# -PRON- edit
# edit be
# good cunt
# cunt like
# -PRON- who
# who revert
# revert good
# good edit
# edit because
# be too
# too stupid
# stupid to
# to understand
# understand how
# how to
# to write
# write good
# good and
# and then
# then revert
# revert other
# other edit
# edit just
# just because
# have decide
# decide to
# to bear
# bear a
# a playground
# playground grudge
# grudge be
# be the
# the problem
# problem maybe
# maybe one
# one day
# day -PRON-
# -PRON- will
# will realise
# realise the
# the damage
# damage -PRON-
# do to
# to a
# a noble
# noble project
# all of -PRON-
# of -PRON- edit
# -PRON- edit be
# edit be good
# be good cunt
# good cunt like
# cunt like -PRON-
# like -PRON- who
# -PRON- who revert
# who revert good
# revert good edit
# good edit because
# edit because -PRON-
# -PRON- be too
# be too stupid
# too stupid to
# stupid to understand
# to understand how
# understand how to
# how to write
# to write good
# write good and
# good and then
# and then revert
# then revert other
# revert other edit
# other edit just
# edit just because
# just because -PRON-
# because -PRON- have
# -PRON- have decide
# have decide to
# decide to bear
# to bear a
# bear a playground
# a playground grudge
# playground grudge be
# grudge be the
# be the problem
# the problem maybe
# problem maybe one
# maybe one day
# one day -PRON-
# day -PRON- will
# -PRON- will realise
# will realise the
# realise the damage
# the damage -PRON-
# damage -PRON- do
# -PRON- do to
# do to a
# to a noble
# a noble project
# all
# edit
# cunt
# revert
# understand
# other
# decide
# bear
# playground
# grudge
# problem
# day
# realise
# damage
# noble
# project
# hello i
# be back
# back again
# again last
# warn stop
# stop undo
# undo -PRON-
# edit or
# or die
# hello i be
# i be back
# be back again
# back again last
# again last warn
# last warn stop
# warn stop undo
# stop undo -PRON-
# undo -PRON- edit
# -PRON- edit or
# edit or die
# hello
# undo
# would -PRON-
# -PRON- both
# both shut
# shut up
# not run
# run wikipedia
# wikipedia especially
# especially a
# a stupid
# stupid kid
# would -PRON- both
# -PRON- both shut
# both shut up
# shut up -PRON-
# up -PRON- do
# do not run
# not run wikipedia
# run wikipedia especially
# wikipedia especially a
# especially a stupid
# a stupid kid
# both
# shut
# run
# especially
# kid
# a pair
# pair of
# of jewhat
# jewhat wein
# wein nazi
# nazi schmuck
# a pair of
# pair of jewhat
# of jewhat wein
# jewhat wein nazi
# wein nazi schmuck
# pair
# jewhat
# wein
# schmuck
# sorry puck
# puck but
# but no
# no one
# one ever
# ever say
# say dick
# dick be
# be numb
# numb one
# one but
# but -PRON-
# be clearly
# clearly list
# list a
# a be
# be 2
# 2 only
# only to
# to batman
# batman and
# and a
# a master
# master detective
# detective and
# and martial
# martial artist
# artist and
# and be
# be train
# train in
# in all
# all the
# the mention
# mention combat
# combat discpline
# discpline no
# no need
# need to
# to mention
# mention in
# in skillsabilitie
# skillsabilitie about
# about the
# the battle
# battle -PRON-
# -PRON- s
# s lose
# lose and
# and win
# win because
# because that
# s not
# not what
# what a
# a encylopia
# encylopia be
# be suppose
# suppose to
# do conjurer
# conjurer what
# -PRON- problem
# problem be
# -PRON- go
# go by
# by low
# low end
# end showing
# showing and
# not high
# high end
# showing where
# where -PRON-
# s prove
# prove much
# much than
# than a
# a match
# match for
# a meta
# meta like
# like slade
# slade and
# and pin
# pin shiva
# shiva down
# down in
# in one
# one of
# -PRON- early
# early appearence
# sorry puck but
# puck but no
# but no one
# no one ever
# one ever say
# ever say dick
# say dick be
# dick be numb
# be numb one
# numb one but
# one but -PRON-
# but -PRON- be
# -PRON- be clearly
# be clearly list
# clearly list a
# list a be
# a be 2
# be 2 only
# 2 only to
# only to batman
# to batman and
# batman and a
# and a master
# a master detective
# master detective and
# detective and martial
# and martial artist
# martial artist and
# artist and be
# and be train
# be train in
# train in all
# in all the
# all the mention
# the mention combat
# mention combat discpline
# combat discpline no
# discpline no need
# no need to
# need to mention
# to mention in
# mention in skillsabilitie
# in skillsabilitie about
# skillsabilitie about the
# about the battle
# the battle -PRON-
# battle -PRON- s
# -PRON- s lose
# s lose and
# lose and win
# and win because
# win because that
# because that s
# that s not
# s not what
# not what a
# what a encylopia
# a encylopia be
# encylopia be suppose
# be suppose to
# suppose to do
# to do conjurer
# do conjurer what
# conjurer what -PRON-
# what -PRON- problem
# -PRON- problem be
# problem be -PRON-
# be -PRON- go
# -PRON- go by
# go by low
# by low end
# low end showing
# end showing and
# showing and not
# and not high
# not high end
# high end showing
# end showing where
# showing where -PRON-
# where -PRON- s
# -PRON- s prove
# s prove much
# prove much than
# much than a
# than a match
# a match for
# match for a
# for a meta
# a meta like
# meta like slade
# like slade and
# slade and pin
# and pin shiva
# pin shiva down
# shiva down in
# down in one
# in one of
# one of -PRON-
# of -PRON- early
# -PRON- early appearence
# puck
# ever
# numb
# clearly
# list
# only
# batman
# master
# detective
# martial
# artist
# train
# mention
# combat
# discpline
# need
# skillsabilitie
# battle
# lose
# win
# encylopia
# suppose
# conjurer
# by
# low
# end
# showing
# high
# where
# prove
# match
# meta
# slade
# pin
# shiva
# early
# unblock -PRON-
# ill get
# get -PRON-
# -PRON- lawyer
# lawyer on
# on to
# -PRON- for
# for block
# block -PRON-
# -PRON- constitutional
# constitutional right
# right to
# to free
# free speech
# unblock -PRON- or
# or ill get
# ill get -PRON-
# get -PRON- lawyer
# -PRON- lawyer on
# lawyer on to
# on to -PRON-
# to -PRON- for
# -PRON- for block
# for block -PRON-
# block -PRON- constitutional
# -PRON- constitutional right
# constitutional right to
# right to free
# to free speech
# unblock
# lawyer
# block
# constitutional
# free
# speech
# should be
# be fire
# fire -PRON-
# a moronic
# moronic wimp
# wimp who
# who be
# too lazy
# lazy to
# do research
# research -PRON-
# -PRON- make
# -PRON- sick
# sick that
# that people
# people like
# -PRON- exist
# exist in
# in this
# this world
# -PRON- should be
# should be fire
# be fire -PRON-
# fire -PRON- be
# be a moronic
# a moronic wimp
# moronic wimp who
# wimp who be
# who be too
# be too lazy
# too lazy to
# lazy to do
# to do research
# do research -PRON-
# research -PRON- make
# -PRON- make -PRON-
# make -PRON- sick
# -PRON- sick that
# sick that people
# that people like
# people like -PRON-
# like -PRON- exist
# -PRON- exist in
# exist in this
# in this world
# fire
# moronic
# wimp
# lazy
# research
# sick
# exist
# this
# world
# i think
# think that
# a fagget
# fagget get
# a oife
# oife and
# and burn
# burn in
# in hell
# hell i
# i hate
# hate -PRON-
# not have
# have any
# much sex
# sex -PRON-
# be run
# run out
# out of
# of conndom
# i think that
# think that -PRON-
# that -PRON- a
# -PRON- a fagget
# a fagget get
# fagget get a
# get a oife
# a oife and
# oife and burn
# and burn in
# burn in hell
# in hell i
# hell i hate
# i hate -PRON-
# hate -PRON- be
# sorry -PRON- can
# can not have
# not have any
# have any much
# any much sex
# much sex -PRON-
# sex -PRON- be
# -PRON- be run
# be run out
# run out of
# out of conndom
# fagget
# oife
# burn
# hate
# sex
# out
# conndom
# reply above
# above that
# that be
# -PRON- loser
# loser the
# the un
# un define
# define vietnam
# vietnam to
# to be
# be part
# part of
# of southeast
# southeast asia
# asia and
# and far
# far a
# know vietnam
# vietnam be
# of asean
# asean and
# and use
# use to
# of french
# french indochina
# indochina with
# with laos
# laos and
# and all
# all that
# that shit
# shit country
# country anyway
# anyway -PRON-
# -PRON- culture
# culture have
# have always
# always be
# much influence
# influence by
# by sea
# sea than
# than han
# han chinese
# chinese a
# a in
# in proper
# proper yangtze
# yangtze han
# chinese not
# not the
# the fringe
# fringe indigenous
# indigenous tribe
# tribe in
# in guangzhouguangxi
# guangzhouguangxi just
# just admit
# admit that
# -PRON- vietnamese
# vietnamese be
# be all
# all a
# a bunch
# bunch of
# of wannabe
# wannabe crap
# crap people
# people all
# the east
# east asian
# asian people
# people -PRON-
# have speak
# speak to
# to think
# of vietnam
# vietnam a
# a a
# a very
# very integral
# integral part
# of sea
# sea and
# -PRON- all
# all think
# think -PRON-
# be backward
# backward dirty
# dirty and
# and speak
# speak in
# a horrible
# horrible swear
# swear language
# language do
# not matt
# matt what
# what crap
# crap -PRON-
# -PRON- spout
# spout on
# on wikipedia
# wikipedia will
# not change
# change the
# the way
# way people
# people in
# the real
# real world
# world think
# reply above that
# above that be
# that be -PRON-
# be -PRON- loser
# -PRON- loser the
# loser the un
# the un define
# un define vietnam
# define vietnam to
# vietnam to be
# to be part
# be part of
# part of southeast
# of southeast asia
# southeast asia and
# asia and far
# and far a
# far a i
# a i know
# i know vietnam
# know vietnam be
# vietnam be part
# part of asean
# of asean and
# asean and use
# and use to
# use to be
# part of french
# of french indochina
# french indochina with
# indochina with laos
# with laos and
# laos and all
# and all that
# all that shit
# that shit country
# shit country anyway
# country anyway -PRON-
# anyway -PRON- culture
# -PRON- culture have
# culture have always
# have always be
# always be much
# be much influence
# much influence by
# influence by sea
# by sea than
# sea than han
# than han chinese
# han chinese a
# chinese a in
# a in proper
# in proper yangtze
# proper yangtze han
# yangtze han chinese
# han chinese not
# chinese not the
# not the fringe
# the fringe indigenous
# fringe indigenous tribe
# indigenous tribe in
# tribe in guangzhouguangxi
# in guangzhouguangxi just
# guangzhouguangxi just admit
# just admit that
# admit that -PRON-
# that -PRON- vietnamese
# -PRON- vietnamese be
# vietnamese be all
# be all a
# all a bunch
# a bunch of
# bunch of wannabe
# of wannabe crap
# wannabe crap people
# crap people all
# people all the
# all the east
# the east asian
# east asian people
# asian people -PRON-
# people -PRON- have
# -PRON- have speak
# have speak to
# speak to think
# to think of
# think of vietnam
# of vietnam a
# vietnam a a
# a a very
# a very integral
# very integral part
# integral part of
# part of sea
# of sea and
# sea and -PRON-
# and -PRON- all
# -PRON- all think
# all think -PRON-
# think -PRON- be
# -PRON- be backward
# be backward dirty
# backward dirty and
# dirty and speak
# and speak in
# speak in a
# in a horrible
# a horrible swear
# horrible swear language
# swear language do
# language do not
# do not matt
# not matt what
# matt what crap
# what crap -PRON-
# crap -PRON- spout
# -PRON- spout on
# spout on wikipedia
# on wikipedia will
# wikipedia will not
# will not change
# not change the
# change the way
# the way people
# way people in
# people in the
# in the real
# the real world
# real world think
# reply
# loser
# un
# define
# vietnam
# part
# southeast
# asia
# far
# asean
# use
# french
# indochina
# laos
# country
# anyway
# culture
# always
# influence
# sea
# han
# chinese
# proper
# yangtze
# fringe
# indigenous
# tribe
# guangzhouguangxi
# admit
# vietnamese
# bunch
# wannabe
# crap
# east
# asian
# speak
# integral
# backward
# dirty
# horrible
# swear
# language
# matt
# spout
# change
# real
# stupid fuck
# fuck and
# -PRON- mother
# mother cunt
# cunt stink
# be a stupid
# a stupid fuck
# stupid fuck and
# fuck and -PRON-
# and -PRON- mother
# -PRON- mother cunt
# mother cunt stink
# stink
# -PRON- blatant
# blatant pov
# pov push
# push neither
# neither of
# -PRON- guy
# guy have
# have make
# make any
# any contribution
# contribution to
# to this
# this italian
# italian history
# history article
# article other
# other than
# than to
# to shove
# shove -PRON-
# -PRON- unhistorical
# unhistorical unconstructive
# unconstructive modern
# modern pov
# pov in
# -PRON- face
# face this
# this be
# a history
# article history
# history have
# have -PRON-
# -PRON- hear
# hear of
# of that
# that this
# the reason
# reason why
# why so
# so many
# many people
# people get
# get piss
# piss off
# off about
# the pedantry
# pedantry and
# and idiocy
# idiocy and
# and triviality
# triviality of
# of wikipedia
# wikipedia jsus
# jsus get
# a fck
# fck life
# -PRON- blatant pov
# blatant pov push
# pov push neither
# push neither of
# neither of -PRON-
# of -PRON- guy
# -PRON- guy have
# guy have make
# have make any
# make any contribution
# any contribution to
# contribution to this
# to this italian
# this italian history
# italian history article
# history article other
# article other than
# other than to
# than to shove
# to shove -PRON-
# shove -PRON- unhistorical
# -PRON- unhistorical unconstructive
# unhistorical unconstructive modern
# unconstructive modern pov
# modern pov in
# pov in -PRON-
# in -PRON- face
# -PRON- face this
# face this be
# this be a
# be a history
# a history article
# history article history
# article history have
# history have -PRON-
# have -PRON- hear
# -PRON- hear of
# hear of that
# of that this
# that this be
# this be the
# be the reason
# the reason why
# reason why so
# why so many
# so many people
# many people get
# people get piss
# get piss off
# piss off about
# off about the
# about the pedantry
# the pedantry and
# pedantry and idiocy
# and idiocy and
# idiocy and triviality
# and triviality of
# triviality of wikipedia
# of wikipedia jsus
# wikipedia jsus get
# jsus get a
# get a fck
# a fck life
# blatant
# pov
# push
# neither
# guy
# contribution
# italian
# history
# article
# shove
# unhistorical
# unconstructive
# modern
# face
# hear
# reason
# many
# pedantry
# idiocy
# triviality
# jsus
# fck
# give -PRON-
# a permanat
# permanat block
# block raseac
# raseac remember
# remember -PRON-
# -PRON- muslim
# muslim do
# -PRON- worry
# worry for
# for this
# this image
# image -PRON-
# to hurt
# -PRON- but
# look this
# image be
# be fake
# fake and
# and have
# have nothing
# nothing to
# do with
# with islam
# islam or
# or -PRON-
# -PRON- prophet
# prophet even
# even -PRON-
# -PRON- article
# article be
# be so
# so lame
# lame wikipedia
# wikipedia be
# be not
# not a
# a authentic
# authentic source
# source -PRON-
# a encyclopedia
# encyclopedia for
# the kid
# kid which
# which have
# have not
# not authenticity
# authenticity anyone
# anyone can
# can edit
# or write
# write whatev
# whatev -PRON-
# -PRON- thinkjust
# thinkjust like
# like raeasc
# raeasc -PRON-
# can see
# -PRON- doe
# not know
# know what
# what islam
# islam be
# be and
# talk about
# about -PRON-
# -PRON- so
# so forget
# forget about
# about wiki
# wiki -PRON-
# -PRON- lame
# lame -PRON-
# have no
# no authenticityi
# authenticityi recommend
# recommend -PRON-
# should add
# add piss
# piss christ
# christ in
# in jessus
# jessus articlethey
# articlethey should
# give -PRON- a
# -PRON- a permanat
# a permanat block
# permanat block raseac
# block raseac remember
# raseac remember -PRON-
# remember -PRON- muslim
# -PRON- muslim do
# muslim do not
# do not -PRON-
# not -PRON- worry
# -PRON- worry for
# worry for this
# for this image
# this image -PRON-
# image -PRON- be
# try to hurt
# to hurt -PRON-
# hurt -PRON- but
# -PRON- but -PRON-
# but -PRON- can
# can not look
# not look this
# look this image
# this image be
# image be fake
# be fake and
# fake and have
# and have nothing
# have nothing to
# nothing to do
# to do with
# do with islam
# with islam or
# islam or -PRON-
# or -PRON- prophet
# -PRON- prophet even
# prophet even -PRON-
# even -PRON- article
# -PRON- article be
# article be so
# be so lame
# so lame wikipedia
# lame wikipedia be
# wikipedia be not
# be not a
# not a authentic
# a authentic source
# authentic source -PRON-
# source -PRON- a
# -PRON- a encyclopedia
# a encyclopedia for
# encyclopedia for the
# for the kid
# the kid which
# kid which have
# which have not
# have not authenticity
# not authenticity anyone
# authenticity anyone can
# anyone can edit
# can edit or
# edit or write
# or write whatev
# write whatev -PRON-
# whatev -PRON- thinkjust
# -PRON- thinkjust like
# thinkjust like raeasc
# like raeasc -PRON-
# raeasc -PRON- can
# -PRON- can see
# can see -PRON-
# see -PRON- doe
# -PRON- doe not
# doe not know
# not know what
# know what islam
# what islam be
# islam be and
# be and -PRON-
# and -PRON- talk
# -PRON- talk about
# talk about -PRON-
# about -PRON- so
# -PRON- so forget
# so forget about
# forget about wiki
# about wiki -PRON-
# wiki -PRON- lame
# -PRON- lame -PRON-
# lame -PRON- have
# -PRON- have no
# have no authenticityi
# no authenticityi recommend
# authenticityi recommend -PRON-
# recommend -PRON- should
# -PRON- should add
# should add piss
# add piss christ
# piss christ in
# christ in jessus
# in jessus articlethey
# jessus articlethey should
# give
# permanat
# raseac
# remember
# muslim
# worry
# image
# fake
# nothing
# islam
# prophet
# even
# lame
# authentic
# source
# encyclopedia
# which
# authenticity
# anyone
# whatev
# thinkjust
# raeasc
# forget
# wiki
# authenticityi
# recommend
# add
# christ
# jessus
# articlethey
# -PRON- block
# -PRON- faggot
# faggot pussy
# fuck -PRON- block
# -PRON- block -PRON-
# block -PRON- -PRON-
# -PRON- -PRON- faggot
# -PRON- faggot pussy
# faggot
# pussy
# kill all
# all nigger
# nigger i
# have hard
# hard that
# that other
# other have
# have say
# say this
# this should
# should this
# be include
# include that
# that racist
# racist sometimes
# sometimes say
# kill all nigger
# all nigger i
# nigger i have
# i have hard
# have hard that
# hard that other
# that other have
# other have say
# have say this
# say this should
# this should this
# should this be
# this be include
# be include that
# include that racist
# that racist sometimes
# racist sometimes say
# sometimes say this
# kill
# nigger
# hard
# include
# racist
# sometimes
# burn deck
# deck if
# if that
# that have
# have guy
# guy burn
# deck be
# be like
# like what
# what i
# be than
# be in
# in for
# a blrude
# blrude awaken
# awaken leviathan
# leviathan motherfucker
# burn deck if
# deck if that
# if that have
# that have guy
# have guy burn
# guy burn deck
# burn deck be
# deck be like
# be like what
# like what i
# what i think
# i think -PRON-
# -PRON- be than
# be than -PRON-
# than -PRON- be
# -PRON- be in
# be in for
# in for a
# for a blrude
# a blrude awaken
# blrude awaken leviathan
# awaken leviathan motherfucker
# deck
# blrude
# awaken
# leviathan
# motherfucker
# u r
# r a
# a tw
# tw fuck
# fuck off
# off u
# u gay
# gay boyu
# boyu r
# r smellyfuck
# smellyfuck ur
# ur mum
# mum poopie
# u r a
# r a tw
# a tw fuck
# tw fuck off
# fuck off u
# off u gay
# u gay boyu
# gay boyu r
# boyu r smellyfuck
# r smellyfuck ur
# smellyfuck ur mum
# ur mum poopie
# u
# r
# tw
# boyu
# smellyfuck
# ur
# mum
# poopie
# atheism be
# be full
# full of
# of bias
# bias shit
# atheism be full
# be full of
# full of bias
# of bias shit
# atheism
# full
# bias
# hey why
# be spread
# spread misconception
# misconception and
# and try
# to spread
# spread false
# false information
# information to
# the peopleyou
# peopleyou not
# not even
# even know
# know who
# who win
# win the
# battle and
# and who
# who lostyou
# lostyou be
# the cheap
# cheap person
# person on
# the earthbloody
# earthbloody ignorant
# ignorant foolcheck
# foolcheck source
# source before
# before spread
# spread rumor
# hey why -PRON-
# why -PRON- be
# -PRON- be spread
# be spread misconception
# spread misconception and
# misconception and try
# and try to
# try to spread
# to spread false
# spread false information
# false information to
# information to the
# to the peopleyou
# the peopleyou not
# peopleyou not even
# not even know
# even know who
# know who win
# who win the
# win the battle
# the battle and
# battle and who
# and who lostyou
# who lostyou be
# lostyou be the
# be the cheap
# the cheap person
# cheap person on
# person on the
# on the earthbloody
# the earthbloody ignorant
# earthbloody ignorant foolcheck
# ignorant foolcheck source
# foolcheck source before
# source before spread
# before spread rumor
# spread
# misconception
# false
# information
# peopleyou
# lostyou
# cheap
# person
# earthbloody
# ignorant
# foolcheck
# rumor
# be let
# let -PRON-
# -PRON- know
# know when
# when -PRON-
# have crawl
# crawl out
# -PRON- arsis
# arsis dick
# dick laurent
# laurent be
# be dead
# -PRON- be let
# be let -PRON-
# let -PRON- know
# -PRON- know when
# know when -PRON-
# when -PRON- have
# -PRON- have crawl
# have crawl out
# crawl out of
# out of -PRON-
# of -PRON- arsis
# -PRON- arsis dick
# arsis dick laurent
# dick laurent be
# laurent be dead
# let
# when
# crawl
# arsis
# laurent
# this user
# user be
# be such
# such a
# a worthless
# worthless goddamn
# goddamn faggot
# faggot fuck
# this user be
# user be such
# be such a
# such a worthless
# a worthless goddamn
# worthless goddamn faggot
# goddamn faggot fuck
# faggot fuck -PRON-
# fuck -PRON- faggot
# user
# such
# worthless
# goddamn
# off -PRON-
# a administrator
# administrator -PRON-
# the authority
# authority to
# to tell
# tell -PRON-
# -PRON- what
# what to
# fuck off -PRON-
# off -PRON- be
# -PRON- be not
# not a administrator
# a administrator -PRON-
# administrator -PRON- do
# do not have
# not have the
# have the authority
# the authority to
# authority to tell
# to tell -PRON-
# tell -PRON- what
# -PRON- what to
# what to do
# authority
# tell
# good -PRON-
# be ridiculous
# ridiculous in
# in fact
# fact i
# i suspect
# suspect that
# be calton
# calton please
# please block
# not care
# good -PRON- be
# -PRON- be ridiculous
# be ridiculous in
# ridiculous in fact
# in fact i
# fact i suspect
# i suspect that
# suspect that -PRON-
# -PRON- be calton
# be calton please
# calton please block
# please block -PRON-
# block -PRON- i
# -PRON- i do
# do not care
# ridiculous
# fact
# suspect
# calton
# please
# care
# -PRON- award
# award go
# go fuck
# fuck -PRON- fuck
# -PRON- fuck -PRON-
# fuck -PRON- award
# -PRON- award go
# award go fuck
# go fuck -PRON-
# award
# -PRON- eye
# eye on
# one care
# care okay
# okay people
# people can
# can put
# put what
# -PRON- want
# want on
# on here
# here and
# and clean
# clean -PRON-
# -PRON- up
# up all
# all -PRON-
# want but
# care god
# god -PRON-
# so freakin
# freakin stupid
# stupid omnigan
# keep -PRON- eye
# -PRON- eye on
# eye on -PRON-
# on -PRON- no
# -PRON- no one
# no one care
# one care okay
# care okay people
# okay people can
# people can put
# can put what
# put what -PRON-
# what -PRON- want
# -PRON- want on
# want on here
# on here and
# here and clean
# and clean -PRON-
# clean -PRON- up
# -PRON- up all
# up all -PRON-
# all -PRON- want
# -PRON- want but
# want but no
# one care god
# care god -PRON-
# god -PRON- be
# -PRON- be so
# be so freakin
# so freakin stupid
# freakin stupid omnigan
# eye
# okay
# here
# god
# freakin
# omnigan
# matt hardy
# hardy be
# so fuckyitalic
# fuckyitalic textmediaexampleoggmatt
# textmediaexampleoggmatt hardy
# so fucky
# matt hardy be
# hardy be so
# be so fuckyitalic
# so fuckyitalic textmediaexampleoggmatt
# fuckyitalic textmediaexampleoggmatt hardy
# textmediaexampleoggmatt hardy be
# be so fucky
# hardy
# fuckyitalic
# textmediaexampleoggmatt
# fucky
# god be
# dead i
# not mean
# mean to
# to startle
# startle anyone
# anyone but
# but god
# dead -PRON-
# should not
# not worry
# worry about
# anymore just
# just think
# i would
# would let
# let everyone
# everyone know
# know good
# good goodbye
# goodbye and
# and good
# good luck
# luck with
# -PRON- newfound
# newfound crisis
# crisis of
# of faith
# god be dead
# be dead i
# dead i do
# do not mean
# not mean to
# mean to startle
# to startle anyone
# startle anyone but
# anyone but god
# but god be
# be dead -PRON-
# dead -PRON- should
# -PRON- should not
# should not worry
# not worry about
# worry about -PRON-
# about -PRON- anymore
# -PRON- anymore just
# anymore just think
# just think i
# think i would
# i would let
# would let everyone
# let everyone know
# everyone know good
# know good goodbye
# good goodbye and
# goodbye and good
# and good luck
# good luck with
# luck with -PRON-
# with -PRON- newfound
# -PRON- newfound crisis
# newfound crisis of
# crisis of faith
# mean
# startle
# everyone
# goodbye
# luck
# newfound
# crisis
# faith
# see the
# the reference
# reference to
# -PRON- claim
# claim -PRON-
# -PRON- moron
# moron this
# a source
# source it´s
# it´s -PRON-
# -PRON- pov
# pov once
# once i
# have much
# much time
# time i
# will reduce
# reduce -PRON-
# -PRON- pashtun
# pashtun nationalist
# nationalist povs
# povs here
# here on
# on wiki
# wiki and
# and give
# give order
# order to
# -PRON- uncle
# uncle and
# and cousin
# cousin the
# the execution
# execution of
# of pashtun
# pashtun in
# the entire
# entire northern
# northern afghanistan
# afghanistan down
# to gardez
# gardez jalalabad
# jalalabad lashkargah
# lashkargah logar
# logar paghman
# paghman laghman
# laghman kunduz
# kunduz herat
# herat farah
# farah whereever
# whereever immigrant
# immigrant descandant
# descandant of
# of violent
# violent kuchis
# kuchis settle
# settle and
# and take
# take nonpashtun
# nonpashtun land
# land away
# away and
# and traditional
# traditional tajik
# tajik country
# have -PRON- see
# -PRON- see the
# see the reference
# the reference to
# reference to -PRON-
# to -PRON- claim
# -PRON- claim -PRON-
# claim -PRON- moron
# -PRON- moron this
# moron this be
# this be not
# not a source
# a source it´s
# source it´s -PRON-
# it´s -PRON- pov
# -PRON- pov once
# pov once i
# once i have
# i have much
# have much time
# much time i
# time i will
# i will reduce
# will reduce -PRON-
# reduce -PRON- pashtun
# -PRON- pashtun nationalist
# pashtun nationalist povs
# nationalist povs here
# povs here on
# here on wiki
# on wiki and
# wiki and give
# and give order
# give order to
# order to -PRON-
# to -PRON- uncle
# -PRON- uncle and
# uncle and cousin
# and cousin the
# cousin the execution
# the execution of
# execution of pashtun
# of pashtun in
# pashtun in the
# in the entire
# the entire northern
# entire northern afghanistan
# northern afghanistan down
# afghanistan down to
# down to gardez
# to gardez jalalabad
# gardez jalalabad lashkargah
# jalalabad lashkargah logar
# lashkargah logar paghman
# logar paghman laghman
# paghman laghman kunduz
# laghman kunduz herat
# kunduz herat farah
# herat farah whereever
# farah whereever immigrant
# whereever immigrant descandant
# immigrant descandant of
# descandant of violent
# of violent kuchis
# violent kuchis settle
# kuchis settle and
# settle and take
# and take nonpashtun
# take nonpashtun land
# nonpashtun land away
# land away and
# away and traditional
# and traditional tajik
# traditional tajik country
# reference
# claim
# moron
# it´s
# once
# time
# reduce
# pashtun
# nationalist
# povs
# order
# uncle
# cousin
# execution
# entire
# northern
# afghanistan
# gardez
# jalalabad
# lashkargah
# logar
# paghman
# laghman
# kunduz
# herat
# farah
# whereever
# immigrant
# descandant
# violent
# kuchis
# settle
# nonpashtun
# land
# away
# traditional
# tajik
# thank -PRON-
# -PRON- hei
# hei -PRON-
# -PRON- the
# the william
# william hope
# hope fan
# fan guess
# guess what
# back at
# at a
# a new
# new ip
# ip ready
# ready to
# to vandalize
# vandalize everything
# everything regard
# regard william
# hope and
# not do
# do sht
# sht to
# to stop
# stop -PRON-
# maybe delay
# delay -PRON-
# no stop
# so let
# let salute
# salute to
# to some
# much william
# hope lunacy
# lunacy by
# by shove
# -PRON- pnis
# pnis in
# -PRON- mouth
# thank -PRON- hei
# -PRON- hei -PRON-
# hei -PRON- -PRON-
# -PRON- -PRON- the
# -PRON- the william
# the william hope
# william hope fan
# hope fan guess
# fan guess what
# guess what i
# what i be
# be back at
# back at a
# at a new
# a new ip
# new ip ready
# ip ready to
# ready to vandalize
# to vandalize everything
# vandalize everything regard
# everything regard william
# regard william hope
# william hope and
# hope and -PRON-
# and -PRON- can
# can not do
# not do sht
# do sht to
# sht to stop
# to stop -PRON-
# stop -PRON- maybe
# -PRON- maybe delay
# maybe delay -PRON-
# delay -PRON- but
# -PRON- but no
# but no stop
# no stop -PRON-
# stop -PRON- so
# -PRON- so let
# so let salute
# let salute to
# salute to some
# to some much
# some much william
# much william hope
# william hope lunacy
# hope lunacy by
# lunacy by shove
# by shove -PRON-
# shove -PRON- pnis
# -PRON- pnis in
# pnis in -PRON-
# in -PRON- mouth
# thank
# hei
# william
# hope
# fan
# guess
# new
# ip
# ready
# vandalize
# everything
# regard
# sht
# delay
# salute
# lunacy
# pnis
# mouth
# -PRON- userthe
# userthe bohemian
# bohemian shinobis
# shinobis yes
# yes that
# s right
# right bitch
# bitch -PRON-
# all piece
# piece of
# fuck -PRON- userthe
# -PRON- userthe bohemian
# userthe bohemian shinobis
# bohemian shinobis yes
# shinobis yes that
# yes that s
# that s right
# s right bitch
# right bitch -PRON-
# bitch -PRON- be
# -PRON- be all
# be all piece
# all piece of
# piece of shit
# userthe
# bohemian
# shinobis
# bitch
# piece
# dear mokele
# mokele -PRON-
# no right
# tell people
# people to
# to die
# die in
# a fire
# fire just
# that ip
# ip address
# address be
# be be
# be use
# use for
# for vandilism
# vandilism doe
# mean -PRON-
# can talk
# to people
# like that
# fact a
# a big
# big loser
# loser than
# than the
# the person
# person who
# who -PRON-
# dear mokele -PRON-
# mokele -PRON- have
# have no right
# no right to
# right to tell
# to tell people
# tell people to
# people to die
# to die in
# die in a
# in a fire
# a fire just
# fire just because
# just because that
# because that ip
# that ip address
# ip address be
# address be be
# be be use
# be use for
# use for vandilism
# for vandilism doe
# vandilism doe not
# doe not mean
# not mean -PRON-
# mean -PRON- can
# -PRON- can talk
# can talk to
# talk to people
# to people like
# people like that
# like that -PRON-
# be in fact
# in fact a
# fact a big
# a big loser
# big loser than
# loser than the
# than the person
# the person who
# person who -PRON-
# who -PRON- block
# dear
# mokele
# address
# vandilism
# big
# -PRON- racist
# racist experiment
# experiment with
# with the
# the page
# page katherine
# katherine heigl
# heigl on
# wikipedia -PRON-
# -PRON- test
# test work
# work and
# have be
# be revert
# revert or
# or remove
# remove please
# please use
# use the
# the sandbox
# sandbox for
# for any
# any other
# other test
# test -PRON-
# -PRON- may
# may want
# want to
# do take
# take a
# a look
# look at
# at the
# the welcome
# welcome page
# page to
# to learn
# learn much
# much about
# about contribute
# contribute to
# -PRON- encyclopedia
# encyclopedia now
# now go
# racist canuck
# canuck asshole
# asshole u
# u have
# nothing well
# well to
# do than
# than censor
# censor the
# the truth
# truth u
# u goddamn
# goddamn kkkkanuck
# kkkkanuck piece
# piece o
# o trash
# trash dickhead
# dickhead moron
# moron motherfuckerlol
# motherfuckerlol -PRON-
# -PRON- canuck
# canuck r
# r real
# real retard
# retard fuk
# fuk off
# off dickweed
# dickweed edit
# edit another
# another of
# -PRON- eidts
# eidts and
# will be
# be expel
# expel from
# from wiki
# wiki by
# by jimbo
# jimbo -PRON-
# -PRON- sob
# sob dickhead
# dickhead so
# so watch
# watch -PRON-
# -PRON- mofo
# mofo piece
# of garbage
# garbage racist
# racist mofo
# mofo asshole
# asshole -PRON-
# be tryinbg
# tryinbg to
# be nice
# nice here
# here so
# so take
# take what
# i say
# say a
# a complimentyamla
# thank -PRON- for
# -PRON- for -PRON-
# for -PRON- racist
# -PRON- racist experiment
# racist experiment with
# experiment with the
# with the page
# the page katherine
# page katherine heigl
# katherine heigl on
# heigl on wikipedia
# on wikipedia -PRON-
# wikipedia -PRON- test
# -PRON- test work
# test work and
# work and -PRON-
# and -PRON- have
# -PRON- have be
# have be revert
# be revert or
# revert or remove
# or remove please
# remove please use
# please use the
# use the sandbox
# the sandbox for
# sandbox for any
# for any other
# any other test
# other test -PRON-
# ...
# -PRON- activity violate
# activity violate wpcoi
# violate wpcoi regard
# wpcoi regard -PRON-
# regard -PRON- edit
# -PRON- edit on
# on this bio
# this bio goethean
# bio goethean bias
# goethean bias on
# bias on rosakam
# on rosakam which
# rosakam which show
# which show a
# show a systemic
# a systemic bias
# systemic bias but
# bias but then
# then again no
# again no matt
# no matt wikipeidia
# matt wikipeidia policy
# wikipeidia policy and
# policy and ethic
# and ethic only
# ethic only democrat
# only democrat who
# democrat who be
# who be approve
# be approve by
# approve by gothean
# by gothean and
# gothean and -PRON-
# and -PRON- master
# -PRON- master and
# master and wpspa
# and wpspa puppet
# wpspa puppet be
# puppet be allow
# be allow classic
# allow classic case
# classic case of
# case of wpown
# of wpown only
# wpown only dccc
# only dccc point
# dccc point of
# view be approve
# be approve let
# approve let just
# let just lose
# just lose the
# lose the pretense
# the pretense of
# pretense of fairness
# of fairness here
# fairness here and
# and just consider
# just consider this
# consider this bio
# this bio a
# bio a official
# a official dccc
# official dccc online
# dccc online version
# online version and
# version and not
# and not any
# not any thing
# any thing npov
# thing npov and
# npov and far
# and far from
# far from encyclopedic
# from encyclopedic and
# encyclopedic and fair
# and fair all
# fair all of
# all of which
# of which give
# which give much
# give much proof
# much proof that
# proof that section
# that section should
# section should be
# should be revise
# be revise and
# revise and rewrite
# and rewrite to
# rewrite to make
# to make that
# make that responsible
# that responsible accountable
# responsible accountable a
# accountable a word
# a word to
# word to personally
# to personally how
# personally how can
# can -PRON- have
# -PRON- have any
# have any kind
# any kind a
# kind a ethical
# a ethical religion
# ethical religion and
# religion and engage
# and engage in
# engage in such
# in such disingenuous
# such disingenuous and
# disingenuous and behavior
# and behavior contrary
# behavior contrary to
# contrary to -PRON-
# -PRON- own belief
# own belief system
# belief system hindu
# system hindu buda
# hindu buda etc
# buda etc which
# etc which i
# see -PRON- engage
# -PRON- engage in
# engage in on
# in on wikipeida
# on wikipeida i
# wikipeida i wonder
# wonder how -PRON-
# how -PRON- look
# at -PRON- self
# -PRON- self in
# self in the
# in the mirror
# the mirror or
# mirror or even
# or even sleep
# even sleep at
# sleep at night
# at night unless
# night unless -PRON-
# unless -PRON- have
# -PRON- have compartmentalize
# have compartmentalize -PRON-
# compartmentalize -PRON- mind
# -PRON- mind off
# mind off so
# off so good
# so good a
# -PRON- can stay
# can stay sane
# stay sane with
# sane with the
# with the hypocrisy
# the hypocrisy -PRON-
# hypocrisy -PRON- seem
# seem to demonstrate
# to demonstrate by
# demonstrate by -PRON-
# by -PRON- own
# -PRON- own behavior
# own behavior what
# behavior what -PRON-
# do and what
# and what -PRON-
# what -PRON- seem
# seem to believe
# to believe in
# believe in seem
# in seem in
# seem in conflict
# in conflict liescensorship
# conflict liescensorship misinformation
# liescensorship misinformation wikipeidia
# misinformation wikipeidia and
# wikipeidia and -PRON-
# and -PRON- cult
# -PRON- cult of
# cult of lie
# of lie and
# lie and all
# and all cultist
# all cultist fear
# cultist fear true
# fear true and
# true and need
# and need to
# need to engage
# to engage need
# engage need to
# to engage in
# engage in -PRON-
# in -PRON- rather
# -PRON- rather then
# rather then the
# then the light
# the light of
# light of day
# of day only
# day only evil
# only evil can
# evil can exist
# can exist in
# exist in the
# in the dark
# the dark of
# dark of such
# of such to
# such to gothenan
# to gothenan i
# gothenan i have
# i have grow
# have grow up
# grow up in
# up in chicago
# in chicago and
# chicago and see
# and see democrat
# see democrat and
# democrat and -PRON-
# and -PRON- thug
# -PRON- thug beat
# thug beat up
# beat up people
# up people for
# people for pull
# for pull republican
# pull republican vote
# republican vote i
# vote i have
# have see ﻿1
# see ﻿1 hand
# ﻿1 hand i
# hand i have
# have see vote
# see vote fraud
# vote fraud institutionalize
# fraud institutionalize where
# institutionalize where only
# where only democratic
# only democratic vote
# democratic vote be
# vote be count
# be count and
# count and election
# and election steal
# election steal a
# steal a normal
# a normal way
# normal way of
# way of life
# of life with
# life with joke
# with joke like
# joke like dead
# like dead vote
# dead vote or
# vote or vote
# or vote early
# vote early for
# early for often
# for often or
# often or the
# or the wino
# the wino voteall
# wino voteall come
# voteall come for
# come for crook
# for crook country
# crook country political
# country political culture
# political culture do
# culture do not
# believe -PRON- read
# -PRON- read boss
# read boss by
# boss by mike
# by mike roko
# mike roko gothean
# roko gothean -PRON-
# gothean -PRON- so
# -PRON- so full
# of -PRON- elitist
# -PRON- elitist garbage
# elitist garbage and
# garbage and self
# and self righteous
# self righteous self
# righteous self -PRON-
# self -PRON- fail
# -PRON- fail to
# fail to understand
# to understand who
# understand who s
# s the real
# the real thug
# real thug here
# thug here i
# here i live
# i live -PRON-
# live -PRON- and
# -PRON- family in
# family in the
# in the county
# the county of
# county of cook
# of cook crook
# cook crook be
# crook be corruption
# be corruption and
# corruption and taxis
# and taxis be
# taxis be on
# on a scale
# a scale rival
# scale rival a
# rival a bannana
# a bannana republic
# bannana republic a
# republic a blue
# a blue paradise
# blue paradise of
# paradise of corruption
# of corruption so
# corruption so bad
# so bad i
# bad i move
# i move to
# move to dupage
# to dupage to
# dupage to get
# to get away
# get away from
# i say to
# say to -PRON-
# to -PRON- if
# -PRON- if be
# if be so
# be so bad
# so bad in
# bad in dupageand
# in dupageand the
# dupageand the 6
# the 6 then
# 6 then gothenan
# then gothenan move
# gothenan move back
# back to chicago
# to chicago get
# chicago get -PRON-
# ass and -PRON-
# and -PRON- fig
# -PRON- fig buda
# fig buda book
# buda book and
# book and look
# and look at
# at the reality
# the reality and
# reality and stop
# stop the big
# the big lie
# big lie -PRON-
# lie -PRON- foist
# -PRON- foist on
# foist on the
# on the ignorant
# coatrack
# cruft
# melissa
# bean
# jill
# morgenthaler
# bio
# goethean
# roskam
# rosakam
# systemic
# wikipeidia
# ethic
# democrat
# approve
# gothean
# wpspa
# dccc
# pretense
# fairness
# accountable
# disingenuous
# buda
# mirror
# compartmentalize
# hypocrisy
# liescensorship
# misinformation
# cultist
# gothenan
# chicago
# thug
# institutionalize
# democratic
# election
# wino
# voteall
# roko
# elitist
# county
# corruption
# taxis
# scale
# rival
# bannana
# paradise
# dupage
# dupageand
# 6
# fig
# have ask
# ask the
# the dude
# dude to
# city but
# insist upon
# upon keep
# keep bostona
# bostona the
# the center
# center of
# world clearly
# clearly bias
# bias in
# this bastrard
# bastrard on
# to compromise
# compromise or
# or neogotiate
# neogotiate all
# see thing
# or how
# want other
# other to
# i have ask
# have ask the
# ask the dude
# the dude to
# dude to do
# do take out
# out the city
# the city but
# city but -PRON-
# but -PRON- insist
# -PRON- insist upon
# insist upon keep
# upon keep bostona
# keep bostona the
# bostona the center
# the center of
# center of the
# the world clearly
# world clearly bias
# clearly bias in
# bias in no
# in no matt
# no matt what
# matt what this
# what this bastrard
# this bastrard on
# bastrard on wikipedia
# on wikipedia do
# know how to
# how to compromise
# to compromise or
# compromise or neogotiate
# or neogotiate all
# neogotiate all -PRON-
# all -PRON- know
# know be how
# how -PRON- see
# -PRON- see thing
# see thing or
# thing or how
# or how -PRON-
# how -PRON- want
# -PRON- want other
# want other to
# other to see
# to see thing
# bostona
# bastrard
# neogotiate
# love hina
# hina part
# part damm
# damm -PRON-
# -PRON- auto
# auto archivingp
# archivingp damm
# damm vandal
# vandal strike
# strike again
# again so
# for sephiroth
# sephiroth bcr
# bcr rather
# then leave
# general board
# board -PRON-
# even remove
# -PRON- reference
# time angry
# angry anyway
# anyway have
# the character
# character yet
# yet but
# medium addition
# addition -PRON-
# the major
# major work
# work so
# far there
# still load
# load miss
# miss color
# color version
# the manga
# manga anime
# anime manga
# manga character
# character cds
# cds etc
# love hina part
# hina part damm
# part damm -PRON-
# damm -PRON- and
# and -PRON- auto
# -PRON- auto archivingp
# auto archivingp damm
# archivingp damm vandal
# damm vandal strike
# vandal strike again
# strike again so
# again so -PRON-
# have leave a
# leave a message
# a message for
# message for sephiroth
# for sephiroth bcr
# sephiroth bcr rather
# bcr rather then
# rather then leave
# then leave a
# a message on
# message on the
# on the general
# the general board
# general board -PRON-
# board -PRON- even
# -PRON- even remove
# even remove -PRON-
# remove -PRON- reference
# -PRON- reference this
# reference this time
# this time angry
# time angry anyway
# angry anyway have
# anyway have not
# not do the
# do the character
# the character yet
# character yet but
# yet but what
# but what do
# -PRON- think of
# think of the
# of the medium
# the medium addition
# medium addition -PRON-
# addition -PRON- have
# have only do
# only do the
# do the major
# the major work
# major work so
# work so far
# so far there
# far there be
# there be still
# be still load
# still load miss
# load miss color
# miss color version
# color version of
# version of the
# of the manga
# the manga anime
# manga anime manga
# anime manga character
# manga character cds
# character cds etc
# hina
# damm
# auto
# archivingp
# strike
# bcr
# manga
# anime
# cds
# be glad
# statement be
# encyclopedia or
# a charity
# charity case
# case while
# -PRON- fawn
# fawn all
# over each
# other apparently
# apparently charity
# case no
# no be
# encyclopedia anymore
# anymore from
# would hate
# name sling
# sling through
# the mud
# mud for
# -PRON- be glad
# be glad that
# glad that -PRON-
# that -PRON- remove
# remove the statement
# the statement be
# statement be -PRON-
# be -PRON- here
# -PRON- here to
# here to write
# to write a
# write a encyclopedia
# a encyclopedia or
# encyclopedia or be
# here to fuck
# to fuck around
# fuck around a
# around a a
# a a charity
# a charity case
# charity case while
# case while -PRON-
# while -PRON- fawn
# -PRON- fawn all
# fawn all over
# all over each
# over each other
# each other apparently
# other apparently charity
# apparently charity case
# charity case no
# case no be
# no be not
# not a encyclopedia
# a encyclopedia anymore
# encyclopedia anymore from
# anymore from -PRON-
# from -PRON- talk
# page -PRON- would
# -PRON- would hate
# would hate to
# see -PRON- name
# -PRON- name sling
# name sling through
# sling through the
# through the mud
# the mud for
# mud for -PRON-
# for -PRON- cheer
# charity
# sling
# hey queer
# queer andrew
# andrew stop
# stop mess
# mess aroundi
# aroundi -PRON-
# mum lesbian
# lesbian and
# father homosexual
# hey queer andrew
# queer andrew stop
# andrew stop mess
# stop mess aroundi
# mess aroundi -PRON-
# aroundi -PRON- mum
# -PRON- mum lesbian
# mum lesbian and
# lesbian and father
# and father homosexual
# andrew
# aroundi
# lesbian
# gay gay
# be gay gay
# gay gay gay
# tell dark
# dark to
# with moot
# moot and
# and b
# b -PRON-
# fuck idea
# s mess
# mess with
# tell dark to
# dark to stop
# to stop fuck
# stop fuck with
# fuck with moot
# with moot and
# moot and b
# and b -PRON-
# b -PRON- have
# have no fuck
# no fuck idea
# fuck idea what
# what -PRON- s
# -PRON- s mess
# s mess with
# moot
# call idiot
# idiot stupid
# and retard
# retard do
# not qualify
# qualify a
# attack because
# call idiot stupid
# idiot stupid and
# stupid and retard
# and retard do
# retard do not
# do not qualify
# not qualify a
# qualify a a
# a a personal
# personal attack because
# attack because -PRON-
# because -PRON- true
# -PRON- true and
# true and the
# and the only
# way -PRON- would
# would not know
# not know this
# this be because
# qualify
# not threaten
# respond kindly
# kindly to
# to threat
# threat from
# from overinflated
# overinflated doughboy
# do not threaten
# not threaten -PRON-
# threaten -PRON- i
# do not respond
# not respond kindly
# respond kindly to
# kindly to threat
# to threat from
# threat from overinflated
# from overinflated doughboy
# overinflated
# doughboy
# the cunt
# cunt you
# you fuck
# fuck old
# old woman
# the cunt you
# cunt you fuck
# you fuck old
# fuck old woman
# scum of
# the earth
# earth vandal
# -PRON- properly
# source edit
# stupid prick
# scum of the
# of the earth
# the earth vandal
# earth vandal do
# vandal do not
# not change -PRON-
# change -PRON- properly
# -PRON- properly source
# properly source edit
# source edit -PRON-
# edit -PRON- stupid
# -PRON- stupid prick
# record after
# war the
# the warning
# warning the
# the ban
# ban og
# og be
# add back
# in by
# by quintuspetillius
# quintuspetillius in
# in sept
# sept wikipedia
# wikipedia staff
# staff have
# clue and
# and brianann
# brianann macamhlaidh
# macamhlaidh be
# the record after
# record after all
# after all the
# all the crap
# the crap the
# crap the edit
# the edit war
# edit war the
# war the warning
# the warning the
# warning the threat
# threat and the
# and the ban
# the ban og
# ban og be
# og be add
# be add back
# add back in
# back in by
# in by quintuspetillius
# by quintuspetillius in
# quintuspetillius in sept
# in sept wikipedia
# sept wikipedia staff
# wikipedia staff have
# staff have no
# no clue and
# clue and brianann
# and brianann macamhlaidh
# brianann macamhlaidh be
# macamhlaidh be still
# still a fuck
# og
# quintuspetillius
# sept
# staff
# brianann
# macamhlaidh
# about kurd
# kurd actually
# be neutral
# neutral to
# want turkey
# turkey depict
# depict a
# some backward
# backward ass
# ass 3
# 3 world
# world shitehole
# shitehole that
# message to
# pathetic heart
# heart delight
# delight but
# -PRON- email
# email every
# every single
# single kurdish
# kurdish editor
# page about
# -PRON- sadass
# sadass addition
# addition which
# which not
# only bash
# bash turkey
# turkey but
# but conjurer
# conjurer lie
# lie the
# the blame
# blame on
# on kurd
# care about kurd
# about kurd actually
# kurd actually i
# i be neutral
# be neutral to
# neutral to -PRON-
# to -PRON- but
# not want turkey
# want turkey depict
# turkey depict a
# depict a some
# a some backward
# some backward ass
# backward ass 3
# ass 3 world
# 3 world shitehole
# world shitehole that
# shitehole that -PRON-
# that -PRON- try
# look like i
# like i will
# stop -PRON- delete
# delete -PRON- message
# -PRON- message to
# message to -PRON-
# to -PRON- pathetic
# -PRON- pathetic heart
# pathetic heart delight
# heart delight but
# delight but -PRON-
# not stop -PRON-
# stop -PRON- email
# -PRON- email every
# email every single
# every single kurdish
# single kurdish editor
# kurdish editor on
# editor on this
# this page about
# page about -PRON-
# about -PRON- sadass
# -PRON- sadass addition
# sadass addition which
# addition which not
# which not only
# not only bash
# only bash turkey
# bash turkey but
# turkey but conjurer
# but conjurer lie
# conjurer lie the
# lie the blame
# the blame on
# blame on kurd
# depict
# shitehole
# delight
# sadass
# how civil
# civil be
# this who
# conversation between
# between old
# old friend
# friend -PRON-
# how civil be
# civil be this
# be this who
# this who the
# be to but
# to but in
# but in on
# in on a
# on a conversation
# a conversation between
# conversation between old
# between old friend
# old friend -PRON-
# friend -PRON- cunt
# just evil
# evil i
# would find
# find such
# a evil
# evil userbox
# userbox shame
# shame on
# be just evil
# just evil i
# evil i do
# i would find
# would find such
# find such a
# such a evil
# a evil userbox
# evil userbox shame
# userbox shame on
# shame on -PRON-
# a dork
# dork two
# play play
# stupid game
# game talk
# talk contribs
# be a dork
# a dork two
# dork two can
# two can play
# can play play
# play play this
# play this stupid
# this stupid game
# stupid game talk
# game talk contribs
# dork
# nigger be
# gay nigger
# nigger then
# nigger association
# of america
# america be
# right for
# -PRON- yor
# yor moneyz
# -PRON- gay be
# gay be -PRON-
# -PRON- a nigger
# a nigger be
# nigger be -PRON-
# -PRON- a gay
# a gay nigger
# gay nigger then
# nigger then the
# then the gay
# the gay nigger
# gay nigger association
# nigger association of
# association of america
# of america be
# america be right
# be right for
# right for -PRON-
# for -PRON- give
# give -PRON- yor
# -PRON- yor moneyz
# yor
# moneyz
# the agsb
# agsb article
# school so
# i probably
# probably know
# twat aadam
# aadam kreissl
# kreissl be
# of radio
# radio club
# club that
# that sexy
# sexy beast
# beast bthe
# bthe member
# of young
# young enterprise
# enterprise do
# all have
# have nipple
# nipple how
# that two
# two change
# change unconstructive
# unconstructive -PRON-
# a gimp
# undo -PRON- change
# -PRON- change to
# change to the
# to the agsb
# the agsb article
# agsb article i
# article i go
# to the school
# the school so
# school so i
# so i probably
# i probably know
# probably know much
# much about -PRON-
# about -PRON- than
# -PRON- than -PRON-
# -PRON- sad twat
# sad twat aadam

# %%
test = pickle.load(open('test.p','rb'))
CleanDict = pickle.load(open('CleanDict.p','rb'))
sample = pd.read_csv('sample_submission.csv')
feature_model = TfidfVectorizer(vocabulary=CleanDict)
feature_matrix = feature_model.fit_transform(train['comment_text'])
